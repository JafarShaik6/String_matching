# %% [markdown]
# #### Problem Statement :-
# Write a code to match names from list1 (provided in the file: name matching -list1.xlsx) to list2 (name matching – list2.xlsx). The names in list1 have multiple variations of a name and map to exactly one name in list2. Also, provide an accuracy measure of the names matched.

# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import warnings
warnings.filterwarnings("ignore")
# Out:
# /anaconda3/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
data1=pd.read_excel('name matching - list1.xlsx',names=['list1'])
data2=pd.read_excel('name matching task - list2.xlsx',names=['list2'])

# %%
data1['list1']=data1['list1'].str.replace(r"\([^()]*\)","")

# %%
df1=data1['list1'].tolist()
df2=data2['list2'].tolist()

# %% [markdown]
# #### Fuzzywuzzy
# In computer science, fuzzy string matching is the technique of finding strings that match a pattern approximately (rather than exactly). In another word, fuzzy string matching is a type of search that will find matches even when users misspell words or enter only partial words for the search. It is also known as approximate string matching.

# %%
score=[]
for j in range(0,len(df2)):
    score.append(process.extractOne(df1[j],df2,scorer=fuzz.token_set_ratio))
    print(process.extractOne(df1[j],df2,scorer=fuzz.token_set_ratio))
# Out:
# ('PRIME TELECOMMUNICATIONS', 86)
# ('COM SYSTEMS INC', 83)
# ('LOCKHEED MARTIN CORP', 86)
# ('ASK CORPORATION', 85)
# ('HITACHI LTD', 100)
# ('COOK ELECTRIC CO', 81)
# ('ASK CORPORATION', 85)
# ('ON TECHNOLOGY CORP', 91)
# ('TOMAHAWK INDUSTRIES INC', 46)
# ('SEARS CANADA INC', 77)
# ('WORLDCORP INC', 88)
# ('ROCKWELL DRILLING CO', 83)
# ('HMO INTERNATIONAL', 87)
# ('HMO INTERNATIONAL', 87)
# ('MICRON TECHNOLOGY INC', 100)
# ('ITT CORPORATION', 88)
# ('SGI INTERNATIONAL', 94)
# ('GENERAL INSTRUMENT CORP', 88)
# ('MCI INC', 100)
# ('HMO INTERNATIONAL', 87)
# ('AT&T CORP', 100)
# ('SANDY CORPORATION', 91)
# ('CANON INC', 71)
# ('ASK CORPORATION', 85)
# ('COOK ELECTRIC CO', 81)
# ('CADO SYSTEMS CORP', 74)
# ('ASK CORPORATION', 85)
# ('TRIMBLE INC', 78)
# ('MICRON TECHNOLOGY INC', 100)
# ('ATRATECH INC', 88)
# ('TEXAS INSTRUMENTS INC', 89)
# ('SANDY CORPORATION', 91)
# ('HMO INTERNATIONAL', 87)
# ('ASK CORPORATION', 85)
# ('HMO INTERNATIONAL', 87)
# ('HMO INTERNATIONAL', 87)
# ...

# %%
q=data1
match=[i[0] for i in score ]
similarity_score=[i[1] for i in score ]

q['match']=match
q['similarity_score']=similarity_score
q.to_csv('matching.csv')

# %%
# !jupyter nbconvert --to html string_matching.ipynb
# Out:
# [NbConvertApp] Converting notebook string_matching.ipynb to html
# [NbConvertApp] Writing 341942 bytes to string_matching.html
